# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing librabries
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Setting up device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Setting Hyperparameters
learning_rate = 5e-5
batch_size = 128
image_size = 64
channel_img = 3
z_dim = 100
num_epochs = 10
feature_d = 64
feature_g = 64
critic_iterations = 5
lambda_GP = 10

variable = transforms.Compose(
    [
        transforms.Resize((image_size,image_size)),
        transforms.ToTensor(),
        transforms.Normalize(
        [0.5 for _ in range(channel_img)], [0.5 for _ in range(channel_img)]),
    ]
)

# %%
# Define the path to your Google Drive folder
drive_folder_path = '/content/drive/MyDrive/Deep Learning Assign 3/facedetectionDS/'

# Define the transformation you want to apply (replace 'variable' with your specific transformation)
transform = transforms.Compose([transforms.Resize((64, 64)), transforms.ToTensor()])

# Load the dataset from the Google Drive folder
dataset = datasets.ImageFolder(root=drive_folder_path, transform=transform)

# Define your batch size
batch_size = 32

# Create a DataLoader
loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
# Checking the loaded data
print(len(loader))
examples = iter(loader)
samples, _ = next(examples)
print(samples.shape)
# Out:
# 219
# torch.Size([32, 3, 64, 64])

# %%
# Visualizing the dataset images
real_batch = next(iter(loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(torchvision.utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
# Creating Critic Class
class Critic(nn.Module):
    def __init__(self, channel_img, feature_d):
        super().__init__()
        self.disc = nn.Sequential(
            nn.Conv2d(channel_img, feature_d, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),
            self._block(feature_d, feature_d*2, 4, 2, 1),
            self._block(feature_d*2, feature_d*4, 4, 2, 1),
            self._block(feature_d*4, feature_d*8, 4, 2, 1),
            nn.Conv2d(feature_d*8, 1, 4, 2, 0),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.InstanceNorm2d(out_channels, affine = True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
# Creating Generator Class
class Generator(nn.Module):
    def __init__(self, z_dim, channel_img, feature_g):
        super().__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, feature_g*16, 4, 2, 0),
            self._block(feature_g*16, feature_g*8, 4, 2, 1),
            self._block(feature_g*8, feature_g*4, 4, 2, 1),
            self._block(feature_g*4, feature_g*2, 4, 2, 1),
            nn.ConvTranspose2d(feature_g*2, channel_img,4, 2, 1),
            nn.Tanh(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.gen(x)

# %%
# Function to initialize the model weights
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.normal_(m.weight.data, 0.0, 0.02)    # mean = 0, variance = 0.02
        if isinstance(m, nn.ConvTranspose2d):
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        if isinstance(m, nn.BatchNorm2d):
            nn.init.normal_(m.weight.data, 0.0,0.02)

# %%
def gradient_penalty(critic, real, fake, device = 'cpu'):
    batch_size, C, H, W = real.shape
    epsilon = torch.rand(batch_size,1,1,1).repeat(1,C,H,W).to(device)
    interpolated_images = real*epsilon + fake*(1-epsilon)

    # Calculate critic scores
    mixed_scores = critic(interpolated_images)

    gradient = torch.autograd.grad(
        inputs = interpolated_images,
        outputs = mixed_scores,
        grad_outputs = torch.ones_like(mixed_scores),
        create_graph = True,
        retain_graph = True,
    )[0]

    gradient = gradient.view(gradient.shape[0], -1)
    gradient_norm = gradient.norm(2, dim = 1)
    gradient_penalty = torch.mean((gradient_norm - 1)**2)
    return gradient_penalty

# %%
# Creating model objects
critic = Critic(channel_img, feature_d).to(device)
gen = Generator(z_dim, channel_img, feature_g).to(device)
initialize_weights(critic)
initialize_weights(gen)

# %%
# Defining optimizer and loss functions
opt_critic = optim.Adam(critic.parameters(), lr = learning_rate, betas=(0.0, 0.9))
opt_gen = optim.Adam(gen.parameters(), lr= learning_rate, betas=(0.0,0.9))

# %%
# telling the model that the data is for training
gen.train()
# Out:
# Generator(
#   (gen): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(2, 2))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (4): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): Tanh()
#   )
# )

# %%
critic.train()
# Out:
# Critic(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#   )
# )

# %%
# Traning Loop
img_list = []
step = 0

for epoch in range(num_epochs):
    for batch_idx, (real, _) in enumerate(loader):
        real = real.to(device)


        for _ in range(critic_iterations):
            noise = torch.randn(batch_size, z_dim, 1, 1).to(device)
            fake = gen(noise)                                                 # G(z)
            critic_real = critic(real).reshape(-1)
            critic_fake = critic(fake).reshape(-1)
            gp = gradient_penalty(critic, real, fake, device = device)
            loss_critic = -(torch.mean(critic_real) - torch.mean(critic_fake)) + lambda_GP*gp
            #loss_crit.append(loss_critic)
            critic.zero_grad()
            loss_critic.backward(retain_graph = True)
            opt_critic.step()

        # Training Generator : -min E(critic(fgen_fake))
        output = critic(fake).reshape(-1)
        loss_gen = -torch.mean(output)
        #loss_generator.append(loss_gen)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()


        # Printing
        if batch_idx % 100 ==0:
            print(f"Epoch [{epoch+1}/{num_epochs}] Batch : {batch_idx}/{len(loader)} \
            LossD: {loss_critic:.4f}, LossG: {loss_gen:.4f}"
                 )

        step += 1
# Out:
# Epoch [1/10] Batch : 0/219             LossD: 2192.8977, LossG: 0.7826
# Epoch [1/10] Batch : 100/219             LossD: -75.3190, LossG: 86.0132
# Epoch [1/10] Batch : 200/219             LossD: -46.5062, LossG: 112.4902
# Epoch [2/10] Batch : 0/219             LossD: -61.2897, LossG: 120.8814
# Epoch [2/10] Batch : 100/219             LossD: -40.0082, LossG: 120.4146
# Epoch [2/10] Batch : 200/219             LossD: -28.9977, LossG: 119.0057
# Epoch [3/10] Batch : 0/219             LossD: -24.5336, LossG: 119.7029
# Epoch [3/10] Batch : 100/219             LossD: -12.2086, LossG: 118.3960
# Epoch [3/10] Batch : 200/219             LossD: -15.7978, LossG: 105.6249
# Epoch [4/10] Batch : 0/219             LossD: -11.6626, LossG: 111.6476
# Epoch [4/10] Batch : 100/219             LossD: -14.3805, LossG: 108.8907
# Epoch [4/10] Batch : 200/219             LossD: -13.3640, LossG: 107.0947
# Epoch [5/10] Batch : 0/219             LossD: -12.6542, LossG: 109.2487
# Epoch [5/10] Batch : 100/219             LossD: -9.9010, LossG: 106.9585
# Epoch [5/10] Batch : 200/219             LossD: -13.7511, LossG: 105.0865
# Epoch [6/10] Batch : 0/219             LossD: -9.9574, LossG: 110.6745
# Epoch [6/10] Batch : 100/219             LossD: -8.9012, LossG: 106.5434
# Epoch [6/10] Batch : 200/219             LossD: -9.3069, LossG: 109.3171
# Epoch [7/10] Batch : 0/219             LossD: -8.9370, LossG: 101.9654
# Epoch [7/10] Batch : 100/219             LossD: -8.1974, LossG: 103.5201
# Epoch [7/10] Batch : 200/219             LossD: -8.9979, LossG: 102.9980
# Epoch [8/10] Batch : 0/219             LossD: -12.8903, LossG: 98.4718
# Epoch [8/10] Batch : 100/219             LossD: -7.1143, LossG: 100.9648
# Epoch [8/10] Batch : 200/219             LossD: -7.3931, LossG: 98.9331
# Epoch [9/10] Batch : 0/219             LossD: -9.9231, LossG: 99.9383
# Epoch [9/10] Batch : 100/219             LossD: -9.8930, LossG: 97.4014
# Epoch [9/10] Batch : 200/219             LossD: -7.8529, LossG: 98.2407
# Epoch [10/10] Batch : 0/219             LossD: -6.8129, LossG: 96.9979
# Epoch [10/10] Batch : 100/219             LossD: -9.0183, LossG: 96.6962
# Epoch [10/10] Batch : 200/219             LossD: -7.7739, LossG: 95.6765

# %%
# Print model's state_dict
print("Model's state_dict:")
for param_tensor in critic.state_dict():
    #print(param_tensor, "\t", critic.state_dict()[param_tensor].size())
    pass

# Print optimizer's state_dict
print("Optimizer's state_dict:")
for var_name in opt_critic.state_dict():
    #print(var_name, "\t", opt_critic.state_dict()[var_name])
    pass

#torch.save(critic.state_dict(), "model_trained.h5")
torch.save(critic.state_dict(), "Critic_trained.h5")
# Out:
# Model's state_dict:
# Optimizer's state_dict:

# %%
# Print model's state_dict
print("Model's state_dict:")
for param_tensor in gen.state_dict():
    #print(param_tensor, "\t", critic.state_dict()[param_tensor].size())
    pass

# Print optimizer's state_dict
print("Optimizer's state_dict:")
for var_name in opt_gen.state_dict():
    #print(var_name, "\t", opt_critic.state_dict()[var_name])
    pass

torch.save(gen.state_dict(), "Generator_trained.h5")
# Out:
# Model's state_dict:
# Optimizer's state_dict:

# %%
# Update the file path
file_path = '/content/drive/MyDrive/Deep Learning Assign 3/facedetectionDS/Generator_trained (1).h5'

# Load the model
gen_1 = Generator(z_dim, channel_img, feature_g).to(device)
gen_1.load_state_dict(torch.load(file_path, map_location='cuda'))
gen_1.cuda()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-0cdcdc6653f4> in <cell line: 6>()
#       4 # Load the model
#       5 gen_1 = Generator(z_dim, channel_img, feature_g).to(device)
# ----> 6 gen_1.load_state_dict(torch.load(file_path, map_location='cuda'))
#       7 gen_1.cuda()
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     984         pickle_load_args['encoding'] = 'utf-8'
#     985
# --> 986     with _open_file_like(f, 'rb') as opened_file:
#     987         if _is_zipfile(opened_file):
#     988             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     433 def _open_file_like(name_or_buffer, mode):
#     434     if _is_path(name_or_buffer):
# --> 435         return _open_file(name_or_buffer, mode)
#     436     else:
#     437         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     414 class _open_file(_opener):
#     415     def __init__(self, name, mode):
# --> 416         super().__init__(open(name, mode))
#     417
#     418     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Deep Learning Assign 3/facedetectionDS/Generator_trained (1).h5'

# %%
img_list = []
fixed_noise = torch.randn(32, z_dim, 1, 1).to(device)
with torch.no_grad():
    fake = gen_1(fixed_noise).detach().cpu()
img_list.append(torchvision.utils.make_grid(fake, padding=2, normalize=True))

# %%
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]

# %%
critic_1 = Critic(channel_img, feature_d).to(device)
critic_1.load_state_dict(torch.load('../input/wganepoch-7/Critic_trained_epoch_7.h5', map_location='cuda'))
critic_1.cuda()

# %%
# Update the file path
file_path = '/content/drive/MyDrive/Deep Learning Assign 3/facedetectionDS/Generator_trained_epoch_7.h5'

# Load the model
gen_1 = Generator(z_dim, channel_img, feature_g).to(device)
gen_1.load_state_dict(torch.load(file_path, map_location='cuda'))
gen_1.cuda()

# %%
# Defining optimizer and loss functions
opt_critic = optim.Adam(critic_1.parameters(), lr = learning_rate, betas=(0.0, 0.9))
opt_gen = optim.Adam(gen_1.parameters(), lr= learning_rate, betas=(0.0,0.9))

# %%
gen_1.train()
critic_1.train()

# %%
# Traning Loop
img_list = []
step = 0
num_epcohs = 7

for epoch in range(num_epochs):
    for batch_idx, (real, _) in enumerate(loader):
        real = real.to(device)


        for _ in range(critic_iterations):
            noise = torch.randn(batch_size, z_dim, 1, 1).to(device)
            fake = gen_1(noise)                                                 # G(z)
            critic_real = critic_1(real).reshape(-1)
            critic_fake = critic_1(fake).reshape(-1)
            gp = gradient_penalty(critic_1, real, fake, device = device)
            loss_critic = -(torch.mean(critic_real) - torch.mean(critic_fake)) + lambda_GP*gp
            #loss_crit.append(loss_critic)
            critic_1.zero_grad()
            loss_critic.backward(retain_graph = True)
            opt_critic.step()

        # Training Generator : -min E(critic(fgen_fake))
        output = critic_1(fake).reshape(-1)
        loss_gen = -torch.mean(output)
        #loss_generator.append(loss_gen)
        gen_1.zero_grad()
        loss_gen.backward()
        opt_gen.step()


        # Printing
        if batch_idx % 100 ==0:
            print(f"Epoch [{epoch+7}/{num_epochs}] Batch : {batch_idx}/{len(loader)} \
            LossD: {loss_critic:.4f}, LossG: {loss_gen:.4f}"
                 )

        if num_epcohs == 7:
            #torch.save(critic.state_dict(), "model_trained.h5")
            torch.save(critic_1.state_dict(), "Critic_trained_epoch_7.h5")
            torch.save(gen_1.state_dict(), "Generator_trained_epoch_7.h5")


#         if (step % 500 == 0) or ((epoch == num_epochs-1) and (i == len(loader)-1)):
#             with torch.no_grad():
#                 fake = gen(fixed_noise).detach().cpu()
#             img_list.append(torchvision.utils.make_grid(fake, padding=2, normalize=True))

        step += 1

# %%
torch.save(critic_1.state_dict(), "Critic_Final_trained.h5")
torch.save(gen_1.state_dict(), "Generator_Final_trained.h5")

# %%
gen_2 = Generator(z_dim, channel_img, feature_g).to(device)
gen_2.load_state_dict(torch.load('./Generator_Final_trained.h5', map_location='cuda'))
gen_2.cuda()

# %%
img_list = []
fixed_noise = torch.randn(32, z_dim, 1, 1).to(device)
with torch.no_grad():
    fake = gen_2(fixed_noise).detach().cpu()
img_list.append(torchvision.utils.make_grid(fake, padding=2, normalize=True))

# %%
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]
plt.title('Generated Fake Images')|
